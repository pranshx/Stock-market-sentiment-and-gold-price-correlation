# %%
import requests
import csv
from datetime import datetime, timedelta
import time

# %%
# SETTINGS API KEY
API_KEYS = [
# Replace with your real key
]
current_key_index = 0

# %%
# === CONSTANTS ===
CSV_FILE = "twitter_nifty_data.csv"
BASE_URL = "https://api.twitterapi.io/twitter/tweet/advanced_search"

# %%
# Initialize CSV with header
def initialize_csv():
    try:
        with open(CSV_FILE, "x", newline="", encoding="utf-8") as file:
            writer = csv.writer(file)
            writer.writerow(["Date", "Tweet ID", "Content", "Created At", "URL"])
    except FileExistsError:
        pass  # File already exists

# %%
# Query builder
def build_query(since, until):
    return f"#Replace with your query"

# Get headers for current API key
def get_headers():
    return {
        "X-API-Key": API_KEYS[current_key_index]
    }

# %%
# Make API call and auto-switch API key on 429
def fetch_tweets(query):
    global current_key_index
    while current_key_index < len(API_KEYS):
        try:
            response = requests.get(BASE_URL, headers=get_headers(), params={"query": query, "type": "latest"})
            if response.status_code == 429:
                print("Rate limit hit. Switching API key...")
                current_key_index += 1
                continue
            response.raise_for_status()
            return response.json().get("tweets", [])
        except Exception as e:
            print(f"Error: {e}")
            return []
    print("All API keys exhausted.")
    return []

# %%
# Save tweets to one file
def save_tweets(date_str, tweets):
    with open(CSV_FILE, "a", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        for tweet in tweets:
            writer.writerow([
                date_str,
                tweet.get("id", ""),
                tweet.get("text", "").replace("\n", " ").strip(),
                tweet.get("createdAt", ""),
                tweet.get("url", "")
            ])
    print(f"Saved {len(tweets)} tweets for {date_str}")

# %%
# === Main execution ===
initialize_csv()
start_date = datetime(2024, 10, 10)
end_date = datetime(2025, 7, 24)

current_date = start_date
while current_date <= end_date:
    if current_date.weekday() < 5:  # Only Monday to Friday
        since_str = current_date.strftime("%Y-%m-%d")
        until_str = (current_date + timedelta(days=1)).strftime("%Y-%m-%d")
        query = build_query(since_str, until_str)
        print(f"Fetching tweets for: {since_str}")
        tweets = fetch_tweets(query)
        if tweets:
            save_tweets(since_str, tweets)
        time.sleep(1.5)  # To be safe with rate limits
    current_date += timedelta(days=1)
# Out:
# Fetching tweets for: 2024-10-10
# Saved 20 tweets for 2024-10-10
# Fetching tweets for: 2024-10-11
# Saved 19 tweets for 2024-10-11
# Fetching tweets for: 2024-10-14
# Saved 19 tweets for 2024-10-14
# Fetching tweets for: 2024-10-15
# Saved 19 tweets for 2024-10-15
# Fetching tweets for: 2024-10-16
# Saved 19 tweets for 2024-10-16
# Fetching tweets for: 2024-10-17
# Saved 20 tweets for 2024-10-17
# Fetching tweets for: 2024-10-18
# Saved 19 tweets for 2024-10-18
# Fetching tweets for: 2024-10-21
# Saved 16 tweets for 2024-10-21
# Fetching tweets for: 2024-10-22
# Saved 17 tweets for 2024-10-22
# Fetching tweets for: 2024-10-23
# Saved 19 tweets for 2024-10-23
# Fetching tweets for: 2024-10-24
# Saved 20 tweets for 2024-10-24
# Fetching tweets for: 2024-10-25
# Saved 20 tweets for 2024-10-25
# Fetching tweets for: 2024-10-28
# Saved 19 tweets for 2024-10-28
# Fetching tweets for: 2024-10-29
# Saved 20 tweets for 2024-10-29
# Fetching tweets for: 2024-10-30
# Saved 20 tweets for 2024-10-30
# Fetching tweets for: 2024-10-31
# Saved 19 tweets for 2024-10-31
# Fetching tweets for: 2024-11-01
# Saved 3 tweets for 2024-11-01
# Fetching tweets for: 2024-11-04
# Saved 17 tweets for 2024-11-04
# Fetching tweets for: 2024-11-05
# Saved 18 tweets for 2024-11-05
# Fetching tweets for: 2024-11-06
# Saved 20 tweets for 2024-11-06
# Fetching tweets for: 2024-11-07
# Saved 18 tweets for 2024-11-07
# Fetching tweets for: 2024-11-08
# Saved 19 tweets for 2024-11-08
# Fetching tweets for: 2024-11-11
# Saved 19 tweets for 2024-11-11
# Fetching tweets for: 2024-11-12
# Saved 19 tweets for 2024-11-12
# Fetching tweets for: 2024-11-13
# Saved 19 tweets for 2024-11-13
# Fetching tweets for: 2024-11-14
# Saved 13 tweets for 2024-11-14
# Fetching tweets for: 2024-11-15
# Saved 1 tweets for 2024-11-15
# Fetching tweets for: 2024-11-18
# Saved 10 tweets for 2024-11-18
# Fetching tweets for: 2024-11-19
# Saved 8 tweets for 2024-11-19
# Fetching tweets for: 2024-11-20
# Fetching tweets for: 2024-11-21
# Saved 12 tweets for 2024-11-21
# Fetching tweets for: 2024-11-22
# Saved 18 tweets for 2024-11-22
# Fetching tweets for: 2024-11-25
# Saved 19 tweets for 2024-11-25
# Fetching tweets for: 2024-11-26
# Saved 12 tweets for 2024-11-26
# Fetching tweets for: 2024-11-27
# Saved 10 tweets for 2024-11-27
# Fetching tweets for: 2024-11-28
# Saved 7 tweets for 2024-11-28
# Fetching tweets for: 2024-11-29
# Saved 18 tweets for 2024-11-29
# Fetching tweets for: 2024-12-02
# Saved 7 tweets for 2024-12-02
# Fetching tweets for: 2024-12-03
# Saved 9 tweets for 2024-12-03
# Fetching tweets for: 2024-12-04
# Saved 8 tweets for 2024-12-04
# Fetching tweets for: 2024-12-05
# Saved 7 tweets for 2024-12-05
# Fetching tweets for: 2024-12-06
# Saved 19 tweets for 2024-12-06
# Fetching tweets for: 2024-12-09
# Saved 20 tweets for 2024-12-09
# Fetching tweets for: 2024-12-10
# Saved 19 tweets for 2024-12-10
# Fetching tweets for: 2024-12-11
# Saved 20 tweets for 2024-12-11
# Fetching tweets for: 2024-12-12
# Saved 11 tweets for 2024-12-12
# Fetching tweets for: 2024-12-13
# Saved 13 tweets for 2024-12-13
# Fetching tweets for: 2024-12-16
# Saved 9 tweets for 2024-12-16
# Fetching tweets for: 2024-12-17
# Saved 9 tweets for 2024-12-17
# Fetching tweets for: 2024-12-18
# Saved 15 tweets for 2024-12-18
# Fetching tweets for: 2024-12-19
# Saved 13 tweets for 2024-12-19
# Fetching tweets for: 2024-12-20
# Saved 11 tweets for 2024-12-20
# Fetching tweets for: 2024-12-23
# Saved 5 tweets for 2024-12-23
# Fetching tweets for: 2024-12-24
# Saved 6 tweets for 2024-12-24
# Fetching tweets for: 2024-12-25
# Fetching tweets for: 2024-12-26
# Saved 9 tweets for 2024-12-26
# Fetching tweets for: 2024-12-27
# Saved 3 tweets for 2024-12-27
# Fetching tweets for: 2024-12-30
# Saved 7 tweets for 2024-12-30
# Fetching tweets for: 2024-12-31
# Saved 9 tweets for 2024-12-31
# Fetching tweets for: 2025-01-01
# Saved 7 tweets for 2025-01-01
# Fetching tweets for: 2025-01-02
# Saved 14 tweets for 2025-01-02
# Fetching tweets for: 2025-01-03
# Saved 9 tweets for 2025-01-03
# Fetching tweets for: 2025-01-06
# Saved 8 tweets for 2025-01-06
# Fetching tweets for: 2025-01-07
# Saved 7 tweets for 2025-01-07
# Fetching tweets for: 2025-01-08
# Saved 10 tweets for 2025-01-08
# Fetching tweets for: 2025-01-09
# Saved 5 tweets for 2025-01-09
# Fetching tweets for: 2025-01-10
# Saved 7 tweets for 2025-01-10
# Fetching tweets for: 2025-01-13
# Saved 10 tweets for 2025-01-13
# Fetching tweets for: 2025-01-14
# Saved 19 tweets for 2025-01-14
# Fetching tweets for: 2025-01-15
# Saved 14 tweets for 2025-01-15
# Fetching tweets for: 2025-01-16
# Saved 5 tweets for 2025-01-16
# Fetching tweets for: 2025-01-17
# Saved 8 tweets for 2025-01-17
# Fetching tweets for: 2025-01-20
# Saved 11 tweets for 2025-01-20
# Fetching tweets for: 2025-01-21
# Saved 12 tweets for 2025-01-21
# Fetching tweets for: 2025-01-22
# Saved 15 tweets for 2025-01-22
# Fetching tweets for: 2025-01-23
# Saved 19 tweets for 2025-01-23
# Fetching tweets for: 2025-01-24
# Saved 20 tweets for 2025-01-24
# Fetching tweets for: 2025-01-27
# Saved 20 tweets for 2025-01-27
# Fetching tweets for: 2025-01-28
# Saved 17 tweets for 2025-01-28
# Fetching tweets for: 2025-01-29
# Saved 20 tweets for 2025-01-29
# Fetching tweets for: 2025-01-30
# Saved 20 tweets for 2025-01-30
# Fetching tweets for: 2025-01-31
# Saved 15 tweets for 2025-01-31
# Fetching tweets for: 2025-02-03
# Saved 18 tweets for 2025-02-03
# Fetching tweets for: 2025-02-04
# Saved 17 tweets for 2025-02-04
# Fetching tweets for: 2025-02-05
# Saved 17 tweets for 2025-02-05
# Fetching tweets for: 2025-02-06
# Saved 18 tweets for 2025-02-06
# Fetching tweets for: 2025-02-07
# Saved 16 tweets for 2025-02-07
# Fetching tweets for: 2025-02-10
# Saved 12 tweets for 2025-02-10
# Fetching tweets for: 2025-02-11
# Saved 18 tweets for 2025-02-11
# Fetching tweets for: 2025-02-12
# Saved 19 tweets for 2025-02-12
# Fetching tweets for: 2025-02-13
# Saved 20 tweets for 2025-02-13
# Fetching tweets for: 2025-02-14
# Saved 18 tweets for 2025-02-14
# Fetching tweets for: 2025-02-17
# Saved 20 tweets for 2025-02-17
# Fetching tweets for: 2025-02-18
# Saved 19 tweets for 2025-02-18
# Fetching tweets for: 2025-02-19
# Saved 15 tweets for 2025-02-19
# Fetching tweets for: 2025-02-20
# Saved 14 tweets for 2025-02-20
# Fetching tweets for: 2025-02-21
# Saved 19 tweets for 2025-02-21
# Fetching tweets for: 2025-02-24
# Saved 18 tweets for 2025-02-24
# Fetching tweets for: 2025-02-25
# Saved 14 tweets for 2025-02-25
# Fetching tweets for: 2025-02-26
# Saved 1 tweets for 2025-02-26
# Fetching tweets for: 2025-02-27
# Saved 20 tweets for 2025-02-27
# Fetching tweets for: 2025-02-28
# Saved 20 tweets for 2025-02-28
# Fetching tweets for: 2025-03-03
# Saved 11 tweets for 2025-03-03
# Fetching tweets for: 2025-03-04
# Saved 12 tweets for 2025-03-04
# Fetching tweets for: 2025-03-05
# Saved 20 tweets for 2025-03-05
# Fetching tweets for: 2025-03-06
# Saved 20 tweets for 2025-03-06
# Fetching tweets for: 2025-03-07
# Saved 20 tweets for 2025-03-07
# Fetching tweets for: 2025-03-10
# Saved 18 tweets for 2025-03-10
# Fetching tweets for: 2025-03-11
# Saved 18 tweets for 2025-03-11
# Fetching tweets for: 2025-03-12
# Saved 19 tweets for 2025-03-12
# Fetching tweets for: 2025-03-13
# Saved 18 tweets for 2025-03-13
# Fetching tweets for: 2025-03-14
# Saved 3 tweets for 2025-03-14
# Fetching tweets for: 2025-03-17
# Saved 17 tweets for 2025-03-17
# Fetching tweets for: 2025-03-18
# Saved 19 tweets for 2025-03-18
# Fetching tweets for: 2025-03-19
# Saved 14 tweets for 2025-03-19
# Fetching tweets for: 2025-03-20
# Saved 16 tweets for 2025-03-20
# Fetching tweets for: 2025-03-21
# Saved 18 tweets for 2025-03-21
# Fetching tweets for: 2025-03-24
# Saved 19 tweets for 2025-03-24
# Fetching tweets for: 2025-03-25
# Saved 19 tweets for 2025-03-25
# Fetching tweets for: 2025-03-26
# Saved 14 tweets for 2025-03-26
# Fetching tweets for: 2025-03-27
# Saved 10 tweets for 2025-03-27
# Fetching tweets for: 2025-03-28
# Saved 13 tweets for 2025-03-28
# Fetching tweets for: 2025-03-31
# Fetching tweets for: 2025-04-01
# Saved 15 tweets for 2025-04-01
# Fetching tweets for: 2025-04-02
# Saved 19 tweets for 2025-04-02
# Fetching tweets for: 2025-04-03
# Saved 20 tweets for 2025-04-03
# Fetching tweets for: 2025-04-04
# Saved 20 tweets for 2025-04-04
# Fetching tweets for: 2025-04-07
# Saved 19 tweets for 2025-04-07
# Fetching tweets for: 2025-04-08
# Saved 20 tweets for 2025-04-08
# Fetching tweets for: 2025-04-09
# Saved 12 tweets for 2025-04-09
# Fetching tweets for: 2025-04-10
# Saved 1 tweets for 2025-04-10
# Fetching tweets for: 2025-04-11
# Saved 19 tweets for 2025-04-11
# Fetching tweets for: 2025-04-14
# Saved 1 tweets for 2025-04-14
# Fetching tweets for: 2025-04-15
# Saved 16 tweets for 2025-04-15
# Fetching tweets for: 2025-04-16
# Saved 9 tweets for 2025-04-16
# Fetching tweets for: 2025-04-17
# Saved 16 tweets for 2025-04-17
# Fetching tweets for: 2025-04-18
# Fetching tweets for: 2025-04-21
# Saved 20 tweets for 2025-04-21
# Fetching tweets for: 2025-04-22
# Saved 17 tweets for 2025-04-22
# Fetching tweets for: 2025-04-23
# Saved 12 tweets for 2025-04-23
# Fetching tweets for: 2025-04-24
# Saved 11 tweets for 2025-04-24
# Fetching tweets for: 2025-04-25
# Saved 20 tweets for 2025-04-25
# Fetching tweets for: 2025-04-28
# Saved 19 tweets for 2025-04-28
# Fetching tweets for: 2025-04-29
# Saved 15 tweets for 2025-04-29
# Fetching tweets for: 2025-04-30
# Saved 10 tweets for 2025-04-30
# Fetching tweets for: 2025-05-01
# Saved 2 tweets for 2025-05-01
# Fetching tweets for: 2025-05-02
# Saved 10 tweets for 2025-05-02
# Fetching tweets for: 2025-05-05
# Saved 20 tweets for 2025-05-05
# Fetching tweets for: 2025-05-06
# Saved 19 tweets for 2025-05-06
# Fetching tweets for: 2025-05-07
# Saved 16 tweets for 2025-05-07
# Fetching tweets for: 2025-05-08
# Saved 9 tweets for 2025-05-08
# Fetching tweets for: 2025-05-09
# Saved 16 tweets for 2025-05-09
# Fetching tweets for: 2025-05-12
# Saved 19 tweets for 2025-05-12
# Fetching tweets for: 2025-05-13
# Saved 18 tweets for 2025-05-13
# Fetching tweets for: 2025-05-14
# Saved 20 tweets for 2025-05-14
# Fetching tweets for: 2025-05-15
# Saved 16 tweets for 2025-05-15
# Fetching tweets for: 2025-05-16
# Saved 20 tweets for 2025-05-16
# Fetching tweets for: 2025-05-19
# Saved 19 tweets for 2025-05-19
# Fetching tweets for: 2025-05-20
# Saved 20 tweets for 2025-05-20
# Fetching tweets for: 2025-05-21
# Saved 20 tweets for 2025-05-21
# Fetching tweets for: 2025-05-22
# Saved 19 tweets for 2025-05-22
# Fetching tweets for: 2025-05-23
# Saved 18 tweets for 2025-05-23
# Fetching tweets for: 2025-05-26
# Saved 19 tweets for 2025-05-26
# Fetching tweets for: 2025-05-27
# Saved 20 tweets for 2025-05-27
# Fetching tweets for: 2025-05-28
# Saved 17 tweets for 2025-05-28
# Fetching tweets for: 2025-05-29
# Saved 11 tweets for 2025-05-29
# Fetching tweets for: 2025-05-30
# Saved 20 tweets for 2025-05-30
# Fetching tweets for: 2025-06-02
# Saved 7 tweets for 2025-06-02
# Fetching tweets for: 2025-06-03
# Saved 9 tweets for 2025-06-03
# Fetching tweets for: 2025-06-04
# Saved 8 tweets for 2025-06-04
# Fetching tweets for: 2025-06-05
# Saved 7 tweets for 2025-06-05
# Fetching tweets for: 2025-06-06
# Saved 19 tweets for 2025-06-06
# Fetching tweets for: 2025-06-09
# Saved 6 tweets for 2025-06-09
# Fetching tweets for: 2025-06-10
# Saved 18 tweets for 2025-06-10
# Fetching tweets for: 2025-06-11
# Saved 19 tweets for 2025-06-11
# Fetching tweets for: 2025-06-12
# Saved 10 tweets for 2025-06-12
# Fetching tweets for: 2025-06-13
# Saved 17 tweets for 2025-06-13
# Fetching tweets for: 2025-06-16
# Saved 8 tweets for 2025-06-16
# Fetching tweets for: 2025-06-17
# Saved 12 tweets for 2025-06-17
# Fetching tweets for: 2025-06-18
# Saved 18 tweets for 2025-06-18
# Fetching tweets for: 2025-06-19
# Saved 14 tweets for 2025-06-19
# Fetching tweets for: 2025-06-20
# Saved 2 tweets for 2025-06-20
# Fetching tweets for: 2025-06-23
# Saved 7 tweets for 2025-06-23
# Fetching tweets for: 2025-06-24
# Saved 10 tweets for 2025-06-24
# Fetching tweets for: 2025-06-25
# Saved 6 tweets for 2025-06-25
# Fetching tweets for: 2025-06-26
# Saved 6 tweets for 2025-06-26
# Fetching tweets for: 2025-06-27
# Saved 18 tweets for 2025-06-27
# Fetching tweets for: 2025-06-30
# Saved 20 tweets for 2025-06-30
# Fetching tweets for: 2025-07-01
# Saved 19 tweets for 2025-07-01
# Fetching tweets for: 2025-07-02
# Saved 10 tweets for 2025-07-02
# Fetching tweets for: 2025-07-03
# Saved 19 tweets for 2025-07-03
# Fetching tweets for: 2025-07-04
# Saved 11 tweets for 2025-07-04
# Fetching tweets for: 2025-07-07
# Saved 13 tweets for 2025-07-07
# Fetching tweets for: 2025-07-08
# Saved 16 tweets for 2025-07-08
# Fetching tweets for: 2025-07-09
# Saved 20 tweets for 2025-07-09
# Fetching tweets for: 2025-07-10
# Saved 20 tweets for 2025-07-10
# Fetching tweets for: 2025-07-11
# Saved 14 tweets for 2025-07-11
# Fetching tweets for: 2025-07-14
# Saved 7 tweets for 2025-07-14
# Fetching tweets for: 2025-07-15
# Saved 12 tweets for 2025-07-15
# Fetching tweets for: 2025-07-16
# Saved 13 tweets for 2025-07-16
# Fetching tweets for: 2025-07-17
# Saved 9 tweets for 2025-07-17
# Fetching tweets for: 2025-07-18
# Saved 11 tweets for 2025-07-18
# Fetching tweets for: 2025-07-21
# Saved 11 tweets for 2025-07-21
# Fetching tweets for: 2025-07-22
# Saved 10 tweets for 2025-07-22
# Fetching tweets for: 2025-07-23
# Saved 8 tweets for 2025-07-23
# Fetching tweets for: 2025-07-24
# Saved 9 tweets for 2025-07-24
